# %%
import numpy as np
import tensorflow as tf

# %%
# !pip show tensorflow
# Out:
# Name: tensorflow
# Version: 1.13.1
# Summary: TensorFlow is an open source machine learning framework for everyone.
# Home-page: https://www.tensorflow.org/
# Author: Google Inc.
# Author-email: opensource@google.com
# License: Apache 2.0
# Location: /usr/local/lib/python3.6/dist-packages
# Requires: absl-py, keras-preprocessing, keras-applications, astor, six, termcolor, gast, tensorboard, wheel, numpy, grpcio, tensorflow-estimator, protobuf
# Required-by: stable-baselines, magenta, fancyimpute

# %%
coefficients = np.array([[1.], [-10], [25.]])

w = tf.Variable(0, dtype=tf.float32)
x = tf.placeholder(tf.float32, [3,1])

cost = x[0][0]* w**2 + x[1][0]*w + x[2][0]

train = tf.train.GradientDescentOptimizer(0.01).minimize(cost)

init = tf.global_variables_initializer()

session = tf.Session()                  
session.run(init)                            
print(session.run(w))
# Out:
# 0.0

# %%
session.run(train, feed_dict={x:coefficients})
print(session.run(w))
# Out:
# 0.198

# %%
for i in range(1000):
  session.run(train, feed_dict={x:coefficients})
  
print(session.run(w))
# Out:
# 4.999988

# %% [markdown]
# # Code example

# %%
import numpy as np
import tensorflow as tf

coeffs = np.array([
    [1], [-20], [25]
])

w = tf.Variable([0], dtype=tf.float32)
x = tf.placeholder(tf.float32, [3,1])

cost = x[0][0]* w**2 + x[1][0]*w + x[2][0]  # (w-5)**2

train = tf.train.GradientDescentOptimizer(0.01).minimize(cost)
init = tf.global_variables_initializer()

# %%
session =  tf.Session()
session.run(init)
print(session.run(w))
# Out:
# [0.]

# %%
for i in range(1000):
  session.run(train, feed_dict={x:coeffs})
  
print(session.run(w))
# Out:
# [9.999976]

# %%
import numpy as np
import tensorflow as tf

coeffs = np.array([  # w**2 -20w + 25 = (w-10)**2 ==> w=10
    [1], [-20], [25]
])

w = tf.Variable([0], dtype=tf.float32)
x = tf.placeholder(tf.float32, [3,1])

cost = x[0][0]* w**2 + x[1][0]*w + x[2][0]

train = tf.train.GradientDescentOptimizer(0.01).minimize(cost)
init = tf.global_variables_initializer()

# %%
# with tf.Session() as session:
#   session.run(init)
#   print(session.run(w))

# %%
with tf.Session() as session:
  session.run(init)

  
  for i in range(1000):
    session.run(train, feed_dict={x:coeffs})
  
  print(session.run(w))
# Out:
# [9.999976]
