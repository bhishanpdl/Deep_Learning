# %% [markdown]
# # Tutorial Torch
# Book: Deep Learning with PyTorch.
#
# - file:///Users/poudel/OneDrive%20-%20Ohio%20University/Books/DataScience/Deep_Learning/pytorch/Deep%20Learning%20with%20PyTorch%20(%20Vishnu%20Subramanian%20).pdf
#
# - https://github.com/PacktPublishing/Deep-Learning-with-PyTorch

# %% [markdown]
# # Load the Libraries

# %%
import numpy as np
import pandas as pd

import torch
from torch.autograd import Variable
import torch.nn as nn


import importlib_metadata
importlib_metadata.version("torch")
# Out:
# '1.7.0+cu101'

# %% [markdown]
# # Useful Functions

# %%
def show_methods(obj, ncols=4,contains=None):
    lst = [i for i in dir(obj) if i[0]!='_' ]
    if contains is not None:
        lst = [i for i in lst if contains in i]
    df = pd.DataFrame(np.array_split(lst,ncols)).T.fillna('')
    return df

# %% [markdown]
# # Torch Tutorial

# %%
# %%time
n = 10_000
a = torch.rand(n,n)
b = torch.rand(n,n)

a.matmul(b)
# Out:
# CPU times: user 23.8 s, sys: 448 ms, total: 24.2 s
# Wall time: 24.2 s

# %%
# %%time
a = a.cuda()
b = b.cuda()

c = a.matmul(b)
# Out:
# CPU times: user 3.1 s, sys: 1.16 s, total: 4.27 s
# Wall time: 4.28 s

# %%
from torch.autograd import Variable

# %%
x = Variable(torch.ones(2,2),requires_grad=True)
y = x.mean()

y.backward()

# %%
x.grad
# Out:
# tensor([[0.2500, 0.2500],
#         [0.2500, 0.2500]])

# %%
x.data
# Out:
# tensor([[1., 1.],
#         [1., 1.]])

# %% [markdown]
# # Chapter 2

# %%
def get_data():
    train_X = np.asarray([3.3,4.4,5.5,6.71,6.93,4.168,9.779,6.182,7.59,2.167,
                         7.042,10.791,5.313,7.997,5.654,9.27,3.1])
    train_Y = np.asarray([1.7,2.76,2.09,3.19,1.694,1.573,3.366,2.596,2.53,1.221,
                         2.827,3.465,1.65,2.904,2.42,2.94,1.3])
    dtype = torch.FloatTensor # view as similar to reshape but reshape may be copy instead of view
    X = Variable(torch.from_numpy(train_X).type(dtype),requires_grad=False).view(17,1)
    y = Variable(torch.from_numpy(train_Y).type(dtype),requires_grad=False)
    return X,y

# %%
def get_weights():
    w = Variable(torch.randn(1),requires_grad = True)
    b = Variable(torch.randn(1),requires_grad=True)
    return w,b

# %%
def simple_network(x):
    y_pred = torch.matmul(x,w)+b
    return y_pred

# %%
import torch.nn as nn
f = nn.Linear(17,1) # Much simpler.
f
# Out:
# Linear(in_features=17, out_features=1, bias=True)

# %%
show_methods(torch.optim)
# Out:
#           0          1           2             3
# 0      ASGD      AdamW     RMSprop    functional
# 1  Adadelta     Adamax       Rprop  lr_scheduler
# 2   Adagrad      LBFGS         SGD     swa_utils
# 3      Adam  Optimizer  SparseAdam

# %%
show_methods(torch.nn)
# Out:
#                              0  ...                              3
# 0            AdaptiveAvgPool1d  ...                   SmoothL1Loss
# 1            AdaptiveAvgPool2d  ...                 SoftMarginLoss
# 2            AdaptiveAvgPool3d  ...                        Softmax
# 3   AdaptiveLogSoftmaxWithLoss  ...                      Softmax2d
# 4            AdaptiveMaxPool1d  ...                        Softmin
# 5            AdaptiveMaxPool2d  ...                       Softplus
# 6            AdaptiveMaxPool3d  ...                     Softshrink
# 7                 AlphaDropout  ...                       Softsign
# 8                    AvgPool1d  ...                  SyncBatchNorm
# 9                    AvgPool2d  ...                           Tanh
# 10                   AvgPool3d  ...                     Tanhshrink
# 11                     BCELoss  ...                      Threshold
# 12           BCEWithLogitsLoss  ...                    Transformer
# ...

# %%
show_methods(torch.nn.utils)
# Out:
#                                      0  ...                     3
# 0                            clip_grad  ...                   rnn
# 1                       clip_grad_norm  ...         spectral_norm
# 2                      clip_grad_norm_  ...  vector_to_parameters
# 3                     clip_grad_value_  ...           weight_norm
# 4  convert_conv2d_weight_memory_format  ...
#
# [5 rows x 4 columns]

# %%
show_methods(nn,contains='Loss')
# Out:
#                             0  ...                              3
# 0  AdaptiveLogSoftmaxWithLoss  ...                 PoissonNLLLoss
# 1                     BCELoss  ...                   SmoothL1Loss
# 2           BCEWithLogitsLoss  ...                 SoftMarginLoss
# 3                     CTCLoss  ...              TripletMarginLoss
# 4         CosineEmbeddingLoss  ...  TripletMarginWithDistanceLoss
# 5            CrossEntropyLoss  ...
#
# [6 rows x 4 columns]
